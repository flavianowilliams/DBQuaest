# %%
from dbquaest import exam

# %%
teste = exam.Test()

# %%
student = [
    'Flaviano W. Fernandes',
    'Flaviano - IFPR'
    ]
teste.create(1, student, 'LQ2N')

# %%
#from dbquaest import exam
#teste = exam.Test()
#teste.make_exam('LQ2N')

# %%
teste.save()

# %%
#teste = exam.Test()
#teste.delete(2)
#teste.save()
